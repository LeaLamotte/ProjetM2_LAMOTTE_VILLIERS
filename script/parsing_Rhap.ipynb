# %%
def structure(annotations):
    arbre={}
    for ligne in annotations:#Pour chaque ligne du fichier
        #arbre.setdefault(int(ligne[0]), []).append( (ligne[1], ligne[2], ligne[3]) )
        arbre.setdefault(int(ligne[0]), []) #On créer une entrée par arbre
        #Chaque arbre prend une liste de mots (un mot est une liste de tokens)
        if ligne[2]=='B':
            arbre[int(ligne[0])].append( [(ligne[1], ligne[3])] )
        elif ligne[2]=='I':
            arbre[int(ligne[0])][-1].append( (ligne[1], ligne[3]) )
    return arbre

# %%
def structure2xml(structure):
    texte=''
    for arbre in sorted(structure.keys()):#Pour chaque arbre/cle
        texte+='    <arbre n="'+str(arbre)+'">\n'
        for mot in structure[arbre]:#Pour chaque liste de tokens dans cet arbre
            texte+='        <mot pos="'+mot[0][1]+'">\n'
            for token in mot:
                texte+='            <token>'+token[0]+'</token>\n'
            texte+='        </mot>\n'
        texte+='    </arbre>\n'
    return texte

# %%
import os, re

ligneRG=re.compile("[^\t]*\t([^\t]*)\t[^\t]*\t([^\t]*)\t[^\t]*\t([^\t]*)\t[^\t]*\t[^\t]*\t([^\t]*)\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*\t[^\t]*")

with open('Rhapsodie.xml', 'w', encoding='UTF-8') as sortie:
    sortie.write('<root>\n')
    for dossier, sous_dossiers, fichiers in os.walk('../data/Rhapsodie'):
        for fichier in fichiers:
            if fichier.endswith('.tabular'):#Pour tous les fichiers tabulaire du repertoire Rhapsodie
                with open(os.path.join(dossier, fichier), 'r', encoding='UTF-8') as file :#On l'ouvre
                    texte=file.read()#On le lit
                    listLignes=ligneRG.findall(texte)#On récupère ce qui nous interesse
                    #On retire ce qui ne nous interesse pas
                    annotations = [i for i in listLignes if i != ('', ' ', '', '') and i != ('', '', '', '') and i!=('Tree_ID', 'Token', 'Word_span', 'POS')]
                    #On hierarchise les annotations
                    root=structure(annotations)
                    xml=structure2xml(root)
                sortie.write('<fichier'+fichier+'/>\n')
                sortie.write(xml)
    sortie.write('</root>')

# %%
print(xml)
# Out:
# <arbre n="1">
#     <mot pos="I">
#         <token>bonjour</token>
#     </mot>
#     <mot pos="N">
#         <token>Eric</token>
#     </mot>
# </arbre>
# <arbre n="2">
#     <mot pos="N">
#         <token>bonjour</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="Pro">
#         <token>tous</token>
#     </mot>
# </arbre>
# <arbre n="3">
#     <mot pos="Adj">
#         <token>nouvelle</token>
#     </mot>
#     <mot pos="N">
#         <token>nuit</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>pillage</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>affrontement</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>Guadeloupe</token>
#     </mot>
# </arbre>
# <arbre n="4">
#     <mot pos="D">
#         <token>trois</token>
#     </mot>
#     <mot pos="N">
#         <token>policiers</token>
#     </mot>
#     <mot pos="Adj">
#         <token>blessés</token>
#     </mot>
# </arbre>
# <arbre n="5">
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>LKP</token>
#     </mot>
#     <mot pos="V">
#         <token>lance</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>appel</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>calme</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>maire</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>Pointe</token>
#         <token>-</token>
#         <token>à</token>
#         <token>-</token>
#         <token>Pitre</token>
#     </mot>
#     <mot pos="N">
#         <token>Jacques</token>
#     </mot>
#     <mot pos="N">
#         <token>Bangou</token>
#     </mot>
#     <mot pos="V">
#         <token>&</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>cri</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>alarme</token>
#     </mot>
# </arbre>
# <arbre n="6">
#     <mot pos="Cl">
#         <token>nous</token>
#     </mot>
#     <mot pos="V">
#         <token>ferons</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>point</token>
#     </mot>
#     <mot pos="Pre">
#         <token>sur</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>violences</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>direct</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avec</token>
#     </mot>
#     <mot pos="D">
#         <token>notre</token>
#     </mot>
#     <mot pos="N">
#         <token>envoyé</token>
#     </mot>
#     <mot pos="Adj">
#         <token>spécial</token>
#     </mot>
#     <mot pos="N">
#         <token>Sébastien</token>
#     </mot>
#     <mot pos="N">
#         <token>Paour</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>quelques</token>
#     </mot>
#     <mot pos="N">
#         <token>instants</token>
#     </mot>
# </arbre>
# <arbre n="7">
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>crise</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>aux</token>
#     </mot>
#     <mot pos="N">
#         <token>Antilles</token>
#     </mot>
#     <mot pos="Cl">
#         <token>il</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ne</token>
#     </mot>
#     <mot pos="V">
#         <token>devrait</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
#     <mot pos="Cl">
#         <token>en</token>
#     </mot>
#     <mot pos="V">
#         <token>être</token>
#     </mot>
#     <mot pos="N">
#         <token>question</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>sommet</token>
#     </mot>
#     <mot pos="Adj">
#         <token>social</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>Élysée</token>
#     </mot>
#     <mot pos="D">
#         <token>cet</token>
#     </mot>
#     <mot pos="N">
#         <token>après</token>
#         <token>-</token>
#         <token>midi</token>
#     </mot>
# </arbre>
# <arbre n="8">
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>face</token>
#         <token> </token>
#         <token>à</token>
#         <token> </token>
#         <token>face</token>
#     </mot>
#     <mot pos="Adv">
#         <token>très</token>
#     </mot>
#     <mot pos="V">
#         <token>attendu</token>
#     </mot>
#     <mot pos="Pre">
#         <token>entre</token>
#     </mot>
#     <mot pos="N">
#         <token>Nicolas</token>
#     </mot>
#     <mot pos="N">
#         <token>Sarkozy</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>syndicats</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>patronat</token>
#     </mot>
# </arbre>
# <arbre n="9">
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="N">
#         <token>Bernard</token>
#     </mot>
#     <mot pos="N">
#         <token>Van</token>
#         <token> </token>
#         <token>Craeynest</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>CFE</token>
#         <token> </token>
#         <token>CGC</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>priorité</token>
#     </mot>
#     <mot pos="Cl">
#         <token>c</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Adv">
#         <token>bien</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="V">
#         <token>sauver</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>emplois</token>
#     </mot>
# </arbre>
# <arbre n="10">
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>foulée</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>ce</token>
#     </mot>
#     <mot pos="N">
#         <token>sommet</token>
#     </mot>
#     <mot pos="Adj">
#         <token>social</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>vingt</token>
#     </mot>
#     <mot pos="N">
#         <token>heures</token>
#     </mot>
#     <mot pos="D">
#         <token>ce</token>
#     </mot>
#     <mot pos="N">
#         <token>soir</token>
#     </mot>
#     <mot pos="D">
#         <token>une</token>
#     </mot>
#     <mot pos="N">
#         <token>intervention</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>chef</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>État</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>télévision</token>
#     </mot>
# </arbre>
# <arbre n="11">
#     <mot pos="Pre">
#         <token>pendant</token>
#     </mot>
#     <mot pos="D">
#         <token>ce</token>
#     </mot>
#     <mot pos="N">
#         <token>temps</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>étudiants</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>enseignants</token>
#         <token>-</token>
#         <token>chercheurs</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ne</token>
#     </mot>
#     <mot pos="V">
#         <token>désarment</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
# </arbre>
# <arbre n="12">
#     <mot pos="Adj">
#         <token>nouvelle</token>
#     </mot>
#     <mot pos="N">
#         <token>journée</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>action</token>
#     </mot>
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="V">
#         <token>attendant</token>
#     </mot>
#     <mot pos="Pro">
#         <token>celle</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="Adv">
#         <token>demain</token>
#     </mot>
# </arbre>
# <arbre n="13">
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>foire</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>empoigne</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>procès</token>
#     </mot>
#     <mot pos="N">
#         <token>Colonna</token>
#     </mot>
# </arbre>
# <arbre n="14">
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>avocats</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>berger</token>
#     </mot>
#     <mot pos="Adj">
#         <token>corse</token>
#     </mot>
#     <mot pos="V">
#         <token>ont</token>
#     </mot>
#     <mot pos="V">
#         <token>quitté</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>procès</token>
#     </mot>
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
#     <mot pos="N">
#         <token>soir</token>
#     </mot>
# </arbre>
# <arbre n="15">
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>parties</token>
#     </mot>
#     <mot pos="Adj">
#         <token>civiles</token>
#     </mot>
#     <mot pos="V">
#         <token>dénoncent</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>pratiques</token>
#     </mot>
#     <mot pos="Adj">
#         <token>terroristes</token>
#     </mot>
# </arbre>
# <arbre n="16">
#     <mot pos="Qu">
#         <token>quel</token>
#     </mot>
#     <mot pos="N">
#         <token>avenir</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>téléphone</token>
#     </mot>
#     <mot pos="Adj">
#         <token>mobile</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>heure</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>iPhone</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>baladeurs</token>
#     </mot>
# </arbre>
# <arbre n="17">
#     <mot pos="N">
#         <token>réponse</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="V">
#         <token>suivre</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avec</token>
#     </mot>
#     <mot pos="N">
#         <token>Hélène</token>
#     </mot>
#     <mot pos="N">
#         <token>Chevalier</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>congrès</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>Barcelone</token>
#     </mot>
# </arbre>
# <arbre n="18">
#     <mot pos="Cl">
#         <token>c</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>contexte</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="Adv">
#         <token>moins</token>
#     </mot>
#     <mot pos="Adj">
#         <token>tendu</token>
#     </mot>
#     <mot pos="CS">
#         <token>que</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>chef</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>État</token>
#     </mot>
#     <mot pos="V">
#         <token>réunit</token>
#     </mot>
#     <mot pos="N">
#         <token>syndicats</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="N">
#         <token>patronat</token>
#     </mot>
# </arbre>
# <arbre n="19">
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>rendez</token>
#         <token>-</token>
#         <token>vous</token>
#     </mot>
#     <mot pos="V">
#         <token>fixé</token>
#     </mot>
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="Cl">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>avez</token>
#     </mot>
#     <mot pos="V">
#         <token>dit</token>
#     </mot>
#     <mot pos="Pre">
#         <token>après</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="Adj">
#         <token>forte</token>
#     </mot>
#     <mot pos="N">
#         <token>mobilisation</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>vingt</token>
#         <token>-</token>
#         <token>neuf</token>
#     </mot>
#     <mot pos="N">
#         <token>janvier</token>
#     </mot>
#     <mot pos="Adj">
#         <token>dernier</token>
#     </mot>
# </arbre>
# <arbre n="20">
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>réunion</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Adv">
#         <token>savamment</token>
#     </mot>
#     <mot pos="V">
#         <token>minutée</token>
#     </mot>
# </arbre>
# <arbre n="21">
#     <mot pos="Adv">
#         <token>alors</token>
#     </mot>
#     <mot pos="Adv">
#         <token>avant</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>aborder</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ce</token>
#     </mot>
#     <mot pos="Qu">
#         <token>qui</token>
#     </mot>
#     <mot pos="V">
#         <token>peut</token>
#     </mot>
#     <mot pos="Cl">
#         <token>en</token>
#     </mot>
#     <mot pos="V">
#         <token>sortir</token>
#     </mot>
#     <mot pos="Cl">
#         <token>je</token>
#     </mot>
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="V">
#         <token>propose</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="V">
#         <token>voir</token>
#     </mot>
#     <mot pos="Qu">
#         <token>où</token>
#     </mot>
#     <mot pos="Qu">
#         <token>quand</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Qu">
#         <token>comment</token>
#     </mot>
#     <mot pos="Pro">
#         <token>cela</token>
#     </mot>
#     <mot pos="V">
#         <token>va</token>
#     </mot>
#     <mot pos="Cl">
#         <token>se</token>
#     </mot>
#     <mot pos="V">
#         <token>passer</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avec</token>
#     </mot>
#     <mot pos="Pro">
#         <token>vous</token>
#     </mot>
#     <mot pos="N">
#         <token>Jean</token>
#         <token>-</token>
#         <token>François</token>
#     </mot>
#     <mot pos="N">
#         <token>Achilli</token>
#     </mot>
# </arbre>
# <arbre n="22">
#     <mot pos="Adv">
#         <token>alors</token>
#     </mot>
#     <mot pos="V">
#         <token>passons</token>
#     </mot>
#     <mot pos="Adv">
#         <token>maintenant</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>détail</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>mesures</token>
#     </mot>
#     <mot pos="V">
#         <token>discutées</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>aux</token>
#     </mot>
#     <mot pos="N">
#         <token>attentes</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>syndicats</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>patronat</token>
#     </mot>
# </arbre>
# <arbre n="23">
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>chef</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>État</token>
#     </mot>
#     <mot pos="V">
#         <token>annonce</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>mesures</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>justice</token>
#     </mot>
#     <mot pos="Cl">
#         <token>je</token>
#     </mot>
#     <mot pos="V">
#         <token>cite</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>salariés</token>
#     </mot>
#     <mot pos="V">
#         <token>touchés</token>
#     </mot>
#     <mot pos="Pre">
#         <token>par</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>crise</token>
#     </mot>
#     <mot pos="Adj">
#         <token>économique</token>
#     </mot>
# </arbre>
# <arbre n="24">
#     <mot pos="J">
#         <token>mais</token>
#     </mot>
#     <mot pos="N">
#         <token>Sara</token>
#     </mot>
#     <mot pos="N">
#         <token>Ghibaudo</token>
#     </mot>
#     <mot pos="Cl">
#         <token>il</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ne</token>
#     </mot>
#     <mot pos="V">
#         <token>pourra</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
#     <mot pos="V">
#         <token>contenter</token>
#     </mot>
#     <mot pos="Adj">
#         <token>tout</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>monde</token>
#     </mot>
# </arbre>
# <arbre n="25">
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>sondage</token>
#     </mot>
#     <mot pos="V">
#         <token>réalisé</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avant</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>rendez</token>
#         <token>-</token>
#         <token>vous</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="Adv">
#         <token>aujourd</token>
#         <token>'</token>
#         <token>hui</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>Français</token>
#     </mot>
#     <mot pos="Cl">
#         <token>se</token>
#     </mot>
#     <mot pos="V">
#         <token>montrent</token>
#     </mot>
#     <mot pos="Adv">
#         <token>très</token>
#     </mot>
#     <mot pos="Adj">
#         <token>sévères</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>égard</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>politique</token>
#     </mot>
#     <mot pos="Adj">
#         <token>économique</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>gouvernement</token>
#     </mot>
#     <mot pos="Qu">
#         <token>qu</token>
#         <token>'</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ils</token>
#     </mot>
#     <mot pos="V">
#         <token>jugent</token>
#     </mot>
#     <mot pos="Adj">
#         <token>mauvaise</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>soixante</token>
#     </mot>
#     <mot pos="N">
#         <token>pour</token>
#         <token> </token>
#         <token>cent</token>
#     </mot>
# </arbre>
# <arbre n="26">
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>mesure</token>
#     </mot>
#     <mot pos="Qu">
#         <token>qu</token>
#         <token>'</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ils</token>
#     </mot>
#     <mot pos="V">
#         <token>attendent</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="Adv">
#         <token>plus</token>
#     </mot>
#     <mot pos="Cl">
#         <token>c</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>répartition</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>bénéfices</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>entreprises</token>
#     </mot>
#     <mot pos="Pre">
#         <token>entre</token>
#     </mot>
#     <mot pos="N">
#         <token>patrons</token>
#     </mot>
#     <mot pos="N">
#         <token>actionnaires</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="N">
#         <token>salariés</token>
#     </mot>
# </arbre>
# <arbre n="27">
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>sondage</token>
#     </mot>
#     <mot pos="N">
#         <token>BVA</token>
#     </mot>
#     <mot pos="N">
#         <token>Les</token>
#         <token> </token>
#         <token>Échos</token>
#     </mot>
#     <mot pos="N">
#         <token>France</token>
#     </mot>
#     <mot pos="N">
#         <token>Info</token>
#     </mot>
#     <mot pos="V">
#         <token>réalisé</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="Adj">
#         <token>treize</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Adj">
#         <token>quatorze</token>
#     </mot>
#     <mot pos="N">
#         <token>février</token>
#     </mot>
#     <mot pos="Adj">
#         <token>derniers</token>
#     </mot>
# </arbre>
# <arbre n="28">
#     <mot pos="Adv">
#         <token>au</token>
#         <token> </token>
#         <token>moins</token>
#     </mot>
#     <mot pos="Adj">
#         <token>six</token>
#     </mot>
#     <mot pos="N">
#         <token>blessés</token>
#     </mot>
#     <mot pos="Adj">
#         <token>légers</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>policiers</token>
#     </mot>
# </arbre>
# <arbre n="29">
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>jeunes</token>
#     </mot>
#     <mot pos="Adj">
#         <token>cagoulés</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Adj">
#         <token>armés</token>
#     </mot>
#     <mot pos="V">
#         <token>ont</token>
#     </mot>
#     <mot pos="V">
#         <token>pillé</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>magasins</token>
#     </mot>
#     <mot pos="V">
#         <token>brûlé</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>pneus</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>voitures</token>
#     </mot>
# </arbre>
# <arbre n="30">
#     <mot pos="I">
#         <token>bonjour</token>
#     </mot>
#     <mot pos="N">
#         <token>Sébastien</token>
#     </mot>
#     <mot pos="N">
#         <token>Paour</token>
#     </mot>
# </arbre>
# <arbre n="31">
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="V">
#         <token>trouvez</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>Gosier</token>
#     </mot>
# </arbre>
# <arbre n="32">
#     <mot pos="Qu">
#         <token>où</token>
#     </mot>
#     <mot pos="Cl">
#         <token>en</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>situation</token>
#     </mot>
# </arbre>
# <arbre n="33">
#     <mot pos="I">
#         <token>merci</token>
#     </mot>
#     <mot pos="N">
#         <token>Sébastien</token>
#     </mot>
#     <mot pos="N">
#         <token>Paour</token>
#     </mot>
# </arbre>
# <arbre n="34">
#     <mot pos="Cl">
#         <token>on</token>
#     </mot>
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="V">
#         <token>retrouve</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="Adj">
#         <token>nouveau</token>
#     </mot>
#     <mot pos="N">
#         <token>point</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>journal</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>huit</token>
#     </mot>
#     <mot pos="N">
#         <token>heures</token>
#     </mot>
# </arbre>
# <arbre n="35">
#     <mot pos="Adj">
#         <token>exact</token>
#     </mot>
# </arbre>
# <arbre n="36">
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="Cl">
#         <token>le</token>
#     </mot>
#     <mot pos="V">
#         <token>savez</token>
#     </mot>
# </arbre>
# <arbre n="37">
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="Cl">
#         <token>y</token>
#     </mot>
#     <mot pos="V">
#         <token>étiez</token>
#     </mot>
#     <mot pos="Cl">
#         <token>il</token>
#     </mot>
#     <mot pos="Cl">
#         <token>y</token>
#     </mot>
#     <mot pos="V">
#         <token>a</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
#     <mot pos="Adv">
#         <token>longtemps</token>
#     </mot>
# </arbre>
# <arbre n="38">
#     <mot pos="Adj">
#         <token>tout</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>monde</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Adv">
#         <token>maintenant</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="D">
#         <token>tout</token>
#     </mot>
#     <mot pos="N">
#         <token>cas</token>
#     </mot>
#     <mot pos="V">
#         <token>suspendu</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="Pro">
#         <token>ce</token>
#     </mot>
#     <mot pos="Qu">
#         <token>que</token>
#     </mot>
#     <mot pos="N">
#         <token>Nicolas</token>
#     </mot>
#     <mot pos="N">
#         <token>Sarkozy</token>
#     </mot>
#     <mot pos="V">
#         <token>annoncera</token>
#     </mot>
#     <mot pos="Adv">
#         <token>demain</token>
#     </mot>
#     <mot pos="Adv">
#         <token>lors</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>sa</token>
#     </mot>
#     <mot pos="N">
#         <token>rencontre</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>Élysée</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avec</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>élus</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>outre</token>
#         <token>-</token>
#         <token>mer</token>
#     </mot>
# </arbre>
# <arbre n="39">
#     <mot pos="Pre">
#         <token>pendant</token>
#     </mot>
#     <mot pos="D">
#         <token>ce</token>
#     </mot>
#     <mot pos="N">
#         <token>temps</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>métropole</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>contestation</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ne</token>
#     </mot>
#     <mot pos="V">
#         <token>faiblit</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>enseignement</token>
#     </mot>
# </arbre>
# <arbre n="40">
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
#     <mot pos="N">
#         <token>tour</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>chauffe</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avant</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="Adj">
#         <token>grande</token>
#     </mot>
#     <mot pos="N">
#         <token>mobilisation</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="Adv">
#         <token>demain</token>
#     </mot>
# </arbre>
# <arbre n="41">
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>millier</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>personnes</token>
#     </mot>
#     <mot pos="V">
#         <token>était</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>rues</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>Poitiers</token>
#     </mot>
# </arbre>
# <arbre n="42">
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>cours</token>
#     </mot>
#     <mot pos="V">
#         <token>étaient</token>
#     </mot>
#     <mot pos="V">
#         <token>suspendus</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>Pau</token>
#     </mot>
# </arbre>
# <arbre n="43">
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>Paris</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>rassemblement</token>
#     </mot>
#     <mot pos="Pre">
#         <token>devant</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>ministère</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>enseignement</token>
#     </mot>
#     <mot pos="Adj">
#         <token>supérieur</token>
#     </mot>
# </arbre>
# <arbre n="44">
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>syndicats</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>cet</token>
#     </mot>
#     <mot pos="N">
#         <token>enseignement</token>
#     </mot>
#     <mot pos="Adj">
#         <token>supérieur</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>Unef</token>
#     </mot>
#     <mot pos="V">
#         <token>réclament</token>
#     </mot>
#     <mot pos="Adv">
#         <token>toujours</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>abandon</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>réformes</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>cours</token>
#     </mot>
# </arbre>
# <arbre n="45">
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>président</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>Unef</token>
#     </mot>
#     <mot pos="N">
#         <token>Jean</token>
#         <token>-</token>
#         <token>Baptiste</token>
#     </mot>
#     <mot pos="N">
#         <token>Prévot</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>micro</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>Sonia</token>
#     </mot>
#     <mot pos="N">
#         <token>Bourane</token>
#     </mot>
# </arbre>
# <arbre n="46">
#     <mot pos="Pre+D">
#         <token>aux</token>
#     </mot>
#     <mot pos="N">
#         <token>États</token>
#         <token>-</token>
#         <token>Unis</token>
#     </mot>
#     <mot pos="N">
#         <token>Barack</token>
#     </mot>
#     <mot pos="N">
#         <token>Obama</token>
#     </mot>
#     <mot pos="V">
#         <token>a</token>
#     </mot>
#     <mot pos="V">
#         <token>promulgué</token>
#     </mot>
#     <mot pos="D">
#         <token>son</token>
#     </mot>
#     <mot pos="N">
#         <token>plan</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>relance</token>
#     </mot>
#     <mot pos="V">
#         <token>adopté</token>
#     </mot>
#     <mot pos="D">
#         <token>ce</token>
#     </mot>
#     <mot pos="N">
#         <token>week</token>
#         <token>-</token>
#         <token>end</token>
#     </mot>
#     <mot pos="Pre">
#         <token>par</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>congrès</token>
#     </mot>
# </arbre>
# <arbre n="47">
#     <mot pos="D">
#         <token>sept</token>
#         <token> </token>
#         <token>cent</token>
#         <token> </token>
#         <token>quatre</token>
#         <token>-</token>
#         <token>vingt</token>
#         <token>-</token>
#         <token>sept</token>
#     </mot>
#     <mot pos="N">
#         <token>milliards</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>dollars</token>
#     </mot>
#     <mot pos="V">
#         <token>destinés</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="V">
#         <token>sauver</token>
#     </mot>
#     <mot pos="J">
#         <token>ou</token>
#     </mot>
#     <mot pos="V">
#         <token>créer</token>
#     </mot>
#     <mot pos="Adv">
#         <token>plus</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>trois</token>
#     </mot>
#     <mot pos="N">
#         <token>millions</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Adj">
#         <token>demi</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>emplois</token>
#     </mot>
# </arbre>
# <arbre n="48">
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="Adj">
#         <token>autre</token>
#     </mot>
#     <mot pos="N">
#         <token>plan</token>
#     </mot>
#     <mot pos="V">
#         <token>destiné</token>
#     </mot>
#     <mot pos="Pro">
#         <token>celui</token>
#     </mot>
#     <mot pos="Adv">
#         <token>-</token>
#         <token>là</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="V">
#         <token>ralentir</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>saisies</token>
#     </mot>
#     <mot pos="Adj">
#         <token>immobilières</token>
#     </mot>
#     <mot pos="V">
#         <token>devrait</token>
#     </mot>
#     <mot pos="V">
#         <token>être</token>
#     </mot>
#     <mot pos="V">
#         <token>annoncé</token>
#     </mot>
#     <mot pos="Adv">
#         <token>aujourd</token>
#         <token>'</token>
#         <token>hui</token>
#     </mot>
#     <mot pos="Pre">
#         <token>par</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>président</token>
#     </mot>
#     <mot pos="Adj">
#         <token>américain</token>
#     </mot>
# </arbre>
# <arbre n="49">
#     <mot pos="Pro">
#         <token>cela</token>
#     </mot>
#     <mot pos="V">
#         <token>concerne</token>
#     </mot>
#     <mot pos="D">
#         <token>plusieurs</token>
#     </mot>
#     <mot pos="N">
#         <token>millions</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>américains</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>rue</token>
#     </mot>
#     <mot pos="N">
#         <token>faute</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="V">
#         <token>pouvoir</token>
#     </mot>
#     <mot pos="V">
#         <token>payer</token>
#     </mot>
#     <mot pos="D">
#         <token>leur</token>
#     </mot>
#     <mot pos="N">
#         <token>crédit</token>
#     </mot>
# </arbre>
# <arbre n="50">
#     <mot pos="D">
#         <token>une</token>
#     </mot>
#     <mot pos="N">
#         <token>rallonge</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="V">
#         <token>venir</token>
#     </mot>
#     <mot pos="Adv">
#         <token>également</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>secteur</token>
#     </mot>
#     <mot pos="N">
#         <token>automobile</token>
#     </mot>
# </arbre>
# <arbre n="51">
#     <mot pos="N">
#         <token>General</token>
#         <token> </token>
#         <token>Motors</token>
#     </mot>
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="N">
#         <token>Chrysler</token>
#     </mot>
#     <mot pos="V">
#         <token>ont</token>
#     </mot>
#     <mot pos="V">
#         <token>présenté</token>
#     </mot>
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
#     <mot pos="D">
#         <token>leur</token>
#     </mot>
#     <mot pos="N">
#         <token>plan</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>restructuration</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>administration</token>
#     </mot>
#     <mot pos="N">
#         <token>Obama</token>
#     </mot>
# </arbre>
# <arbre n="52">
#     <mot pos="Cl">
#         <token>ils</token>
#     </mot>
#     <mot pos="V">
#         <token>demandent</token>
#     </mot>
#     <mot pos="D">
#         <token>vingt</token>
#         <token>-</token>
#         <token>deux</token>
#     </mot>
#     <mot pos="N">
#         <token>milliards</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>dollars</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>contrepartie</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>suppressions</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>emplois</token>
#     </mot>
#     <mot pos="J">
#         <token>mais</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
#     <mot pos="Adv">
#         <token>seulement</token>
#     </mot>
# </arbre>
# <arbre n="53">
#     <mot pos="Pro">
#         <token>tout</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Adj">
#         <token>bon</token>
#     </mot>
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="Cl">
#         <token>le</token>
#     </mot>
#     <mot pos="V">
#         <token>verrez</token>
#     </mot>
#     <mot pos="Pre">
#         <token>avec</token>
#     </mot>
#     <mot pos="N">
#         <token>Bertrand</token>
#     </mot>
#     <mot pos="N">
#         <token>Vanier</token>
#     </mot>
# </arbre>
# <arbre n="54">
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>affaire</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>évadés</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>prison</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>Moulins</token>
#     </mot>
#     <mot pos="V">
#         <token>arrêtés</token>
#     </mot>
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
#     <mot pos="N">
#         <token>matin</token>
#     </mot>
#     <mot pos="Cl">
#         <token>vous</token>
#     </mot>
#     <mot pos="Cl">
#         <token>le</token>
#     </mot>
#     <mot pos="V">
#         <token>savez</token>
#     </mot>
#     <mot pos="Pre">
#         <token>après</token>
#     </mot>
#     <mot pos="D">
#         <token>trente</token>
#         <token>-</token>
#         <token>six</token>
#     </mot>
#     <mot pos="N">
#         <token>heures</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>cavale</token>
#     </mot>
# </arbre>
# <arbre n="55">
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>compagne</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="Pro">
#         <token>l</token>
#         <token>'</token>
#         <token>un</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>détenus</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Adv">
#         <token>toujours</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>garde</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>vue</token>
#     </mot>
# </arbre>
# <arbre n="56">
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>enquêteurs</token>
#     </mot>
#     <mot pos="V">
#         <token>cherchent</token>
#     </mot>
#     <mot pos="Adv">
#         <token>maintenant</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="V">
#         <token>savoir</token>
#     </mot>
#     <mot pos="CS">
#         <token>si</token>
#     </mot>
#     <mot pos="Cl">
#         <token>elle</token>
#     </mot>
#     <mot pos="V">
#         <token>a</token>
#     </mot>
#     <mot pos="V">
#         <token>été</token>
#     </mot>
#     <mot pos="Adj">
#         <token>complice</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>cette</token>
#     </mot>
#     <mot pos="N">
#         <token>évasion</token>
#     </mot>
# </arbre>
# <arbre n="57">
#     <mot pos="Cl">
#         <token>elle</token>
#     </mot>
#     <mot pos="Cl">
#         <token>se</token>
#     </mot>
#     <mot pos="V">
#         <token>trouvait</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>parloir</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>prison</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>moment</token>
#     </mot>
#     <mot pos="Qu">
#         <token>où</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="Adj">
#         <token>deux</token>
#     </mot>
#     <mot pos="N">
#         <token>détenus</token>
#     </mot>
#     <mot pos="Cl">
#         <token>se</token>
#     </mot>
#     <mot pos="V">
#         <token>sont</token>
#     </mot>
#     <mot pos="V">
#         <token>fait</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>belle</token>
#     </mot>
# </arbre>
# <arbre n="58">
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>procès</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>Yvan</token>
#     </mot>
#     <mot pos="N">
#         <token>Colonna</token>
#     </mot>
#     <mot pos="V">
#         <token>tourne</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>foire</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>empoigne</token>
#     </mot>
# </arbre>
# <arbre n="59">
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>tension</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="Adv">
#         <token>encore</token>
#     </mot>
#     <mot pos="V">
#         <token>montée</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>cran</token>
#     </mot>
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
# </arbre>
# <arbre n="60">
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>avocats</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>berger</token>
#     </mot>
#     <mot pos="Adj">
#         <token>corse</token>
#     </mot>
#     <mot pos="V">
#         <token>ont</token>
#     </mot>
#     <mot pos="V">
#         <token>quitté</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>procès</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="V">
#         <token>attendant</token>
#     </mot>
#     <mot pos="CS">
#         <token>que</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>cour</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>assise</token>
#     </mot>
#     <mot pos="Cl">
#         <token>se</token>
#     </mot>
#     <mot pos="V">
#         <token>prononce</token>
#     </mot>
#     <mot pos="Pre">
#         <token>sur</token>
#     </mot>
#     <mot pos="D">
#         <token>leur</token>
#     </mot>
#     <mot pos="N">
#         <token>demande</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>supplément</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>information</token>
#     </mot>
# </arbre>
# <arbre n="61">
#     <mot pos="N">
#         <token>lundi</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>président</token>
#     </mot>
#     <mot pos="V">
#         <token>avait</token>
#     </mot>
#     <mot pos="V">
#         <token>annoncé</token>
#     </mot>
#     <mot pos="CS">
#         <token>qu</token>
#         <token>'</token>
#     </mot>
#     <mot pos="Cl">
#         <token>il</token>
#     </mot>
#     <mot pos="V">
#         <token>rendrait</token>
#     </mot>
#     <mot pos="D">
#         <token>sa</token>
#     </mot>
#     <mot pos="N">
#         <token>décision</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>délai</token>
#     </mot>
#     <mot pos="Adj">
#         <token>raisonnable</token>
#     </mot>
#     <mot pos="Pre">
#         <token>après</token>
#     </mot>
#     <mot pos="V">
#         <token>avoir</token>
#     </mot>
#     <mot pos="V">
#         <token>entendu</token>
#     </mot>
#     <mot pos="Adv">
#         <token>notamment</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="Adj">
#         <token>ancien</token>
#     </mot>
#     <mot pos="N">
#         <token>préfet</token>
#     </mot>
#     <mot pos="N">
#         <token>Bonnet</token>
#     </mot>
# </arbre>
# <arbre n="62">
#     <mot pos="Pre">
#         <token>depuis</token>
#     </mot>
#     <mot pos="N">
#         <token>vendredi</token>
#     </mot>
#     <mot pos="N">
#         <token>soir</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>défense</token>
#     </mot>
#     <mot pos="V">
#         <token>fait</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>forcing</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="V">
#         <token>prendre</token>
#     </mot>
#     <mot pos="D">
#         <token>le</token>
#     </mot>
#     <mot pos="N">
#         <token>contrôle</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>débats</token>
#     </mot>
# </arbre>
# <arbre n="63">
#     <mot pos="Cl">
#         <token>on</token>
#     </mot>
#     <mot pos="V">
#         <token>écoute</token>
#     </mot>
#     <mot pos="N">
#         <token>maître</token>
#     </mot>
#     <mot pos="N">
#         <token>Sollacaro</token>
#     </mot>
#     <mot pos="Cl">
#         <token>il</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>avocat</token>
#     </mot>
#     <mot pos="Pro">
#         <token>l</token>
#         <token>'</token>
#         <token>un</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>avocats</token>
#     </mot>
#     <mot pos="Pre">
#         <token>d</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>Yvan</token>
#     </mot>
#     <mot pos="N">
#         <token>Colonna</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>micro</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>Christian</token>
#     </mot>
#     <mot pos="N">
#         <token>Binner</token>
#     </mot>
# </arbre>
# <arbre n="64">
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="N">
#         <token>Philippe</token>
#     </mot>
#     <mot pos="N">
#         <token>Lemaire</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>avocat</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>parties</token>
#     </mot>
#     <mot pos="Adj">
#         <token>civiles</token>
#     </mot>
#     <mot pos="Cl">
#         <token>c</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>est</token>
#     </mot>
#     <mot pos="D">
#         <token>d~</token>
#     </mot>
#     <mot pos="N">
#         <token>&</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ce</token>
#     </mot>
#     <mot pos="V">
#         <token>sont</token>
#     </mot>
#     <mot pos="D">
#         <token>des</token>
#     </mot>
#     <mot pos="N">
#         <token>procédés</token>
#     </mot>
#     <mot pos="Adj">
#         <token>terroristes</token>
#     </mot>
# </arbre>
# <arbre n="65">
#     <mot pos="Cl">
#         <token>il</token>
#     </mot>
#     <mot pos="Cl">
#         <token>le</token>
#     </mot>
#     <mot pos="V">
#         <token>dit</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>Laurent</token>
#     </mot>
#     <mot pos="N">
#         <token>Doulsant</token>
#     </mot>
# </arbre>
# <arbre n="66">
#     <mot pos="N">
#         <token>direction</token>
#     </mot>
#     <mot pos="Adv">
#         <token>maintenant</token>
#     </mot>
#     <mot pos="N">
#         <token>Barcelone</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>congrès</token>
#     </mot>
#     <mot pos="V">
#         <token>consacré</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>téléphone</token>
#     </mot>
#     <mot pos="Adj">
#         <token>mobile</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>crise</token>
#     </mot>
#     <mot pos="Pro">
#         <token>lui</token>
#     </mot>
#     <mot pos="Adv">
#         <token>aussi</token>
#     </mot>
# </arbre>
# <arbre n="67">
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="Adj">
#         <token>première</token>
#     </mot>
#     <mot pos="N">
#         <token>fois</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>l</token>
#         <token>'</token>
#     </mot>
#     <mot pos="N">
#         <token>histoire</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>du</token>
#     </mot>
#     <mot pos="N">
#         <token>portable</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>ventes</token>
#     </mot>
#     <mot pos="V">
#         <token>devraient</token>
#     </mot>
#     <mot pos="V">
#         <token>baisser</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>deux</token>
#         <token> </token>
#         <token>mille</token>
#         <token> </token>
#         <token>neuf</token>
#     </mot>
# </arbre>
# <arbre n="68">
#     <mot pos="J">
#         <token>et</token>
#     </mot>
#     <mot pos="Pre">
#         <token>derrière</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>sourire</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>façade</token>
#     </mot>
#     <mot pos="D">
#         <token>les</token>
#     </mot>
#     <mot pos="N">
#         <token>constructeurs</token>
#     </mot>
#     <mot pos="Cl">
#         <token>ne</token>
#     </mot>
#     <mot pos="V">
#         <token>réagissent</token>
#     </mot>
#     <mot pos="Adv">
#         <token>pas</token>
#     </mot>
#     <mot pos="Adj">
#         <token>tous</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="Adj">
#         <token>même</token>
#     </mot>
#     <mot pos="N">
#         <token>façon</token>
#     </mot>
#     <mot pos="N">
#         <token>Hélène</token>
#     </mot>
#     <mot pos="N">
#         <token>Chevalier</token>
#     </mot>
# </arbre>
# <arbre n="69">
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="N">
#         <token>mot</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>foot</token>
#     </mot>
# </arbre>
# <arbre n="70">
#     <mot pos="Cl">
#         <token>on</token>
#     </mot>
#     <mot pos="V">
#         <token>jouait</token>
#     </mot>
#     <mot pos="D">
#         <token>trois</token>
#     </mot>
#     <mot pos="N">
#         <token>matchs</token>
#     </mot>
#     <mot pos="Pre">
#         <token>en</token>
#     </mot>
#     <mot pos="N">
#         <token>retard</token>
#     </mot>
#     <mot pos="Pre">
#         <token>dans</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="Adj">
#         <token>vingtième</token>
#     </mot>
#     <mot pos="N">
#         <token>journée</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>ligue</token>
#     </mot>
#     <mot pos="D">
#         <token>un</token>
#     </mot>
#     <mot pos="Adv">
#         <token>hier</token>
#     </mot>
# </arbre>
# <arbre n="71">
#     <mot pos="N">
#         <token>match</token>
#     </mot>
#     <mot pos="Adj">
#         <token>nul</token>
#     </mot>
#     <mot pos="N">
#         <token>zéro</token>
#     </mot>
#     <mot pos="Adv">
#         <token>partout</token>
#     </mot>
#     <mot pos="Pre">
#         <token>pour</token>
#     </mot>
#     <mot pos="N">
#         <token>Lille</token>
#     </mot>
#     <mot pos="Pre+D">
#         <token>au</token>
#     </mot>
#     <mot pos="N">
#         <token>Mans</token>
#     </mot>
# </arbre>
# <arbre n="72">
#     <mot pos="N">
#         <token>Valenciennes</token>
#     </mot>
#     <mot pos="V">
#         <token>sort</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="D">
#         <token>la</token>
#     </mot>
#     <mot pos="N">
#         <token>zone</token>
#     </mot>
#     <mot pos="Pre">
#         <token>de</token>
#     </mot>
#     <mot pos="N">
#         <token>relégation</token>
#     </mot>
#     <mot pos="Pre">
#         <token>après</token>
#     </mot>
#     <mot pos="D">
#         <token>sa</token>
#     </mot>
#     <mot pos="N">
#         <token>victoire</token>
#     </mot>
#     <mot pos="Pre">
#         <token>sur</token>
#     </mot>
#     <mot pos="N">
#         <token>Caen</token>
#     </mot>
#     <mot pos="N">
#         <token>deux</token>
#     </mot>
#     <mot pos="N">
#         <token>zéro</token>
#     </mot>
# </arbre>
# <arbre n="73">
#     <mot pos="N">
#         <token>Nice</token>
#     </mot>
#     <mot pos="Cl">
#         <token>s</token>
#         <token>'</token>
#     </mot>
#     <mot pos="V">
#         <token>impose</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>Nancy</token>
#     </mot>
#     <mot pos="N">
#         <token>deux</token>
#     </mot>
#     <mot pos="Pre">
#         <token>à</token>
#     </mot>
#     <mot pos="N">
#         <token>un</token>
#     </mot>
# </arbre>
